# %%
import io
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import threading
from urllib.parse import urlparse
import urllib.request

opener=urllib.request.build_opener()
stop_words = set(stopwords.words('english'))

def removestopwords(line):
    querywords = line.split()
    resultwords  = [word for word in querywords if word.lower() not in stop_words]
    result = ' '.join(resultwords)
    #print(result)
    return result

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('indian')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package indian to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def convert_list_to_string(org_list, seperator=' '):
    """ Convert list to string, by joining all item in list with given separator.
        Returns the concatenated string """
    return seperator.join(org_list)

# %%
def num_there(s):
    return any(i.isdigit() for i in s)

# %%
from collections import Counter
from math import log
def shannon(string):
    counts = Counter(string)
    #print(counts)
    frequencies = ((i / len(string)) for i in counts.values())
    return - sum(f * log(f, 2) for f in frequencies)

# %%
from statistics import mean
def Average(lst):
    return mean(lst)

# %%
import math
import re
from collections import Counter
WORD = re.compile(r"\w+")


def get_cosine(vec1, vec2):
    intersection = set(vec1.keys()) & set(vec2.keys())
    numerator = sum([vec1[x] * vec2[x] for x in intersection])

    sum1 = sum([vec1[x] ** 2 for x in list(vec1.keys())])
    sum2 = sum([vec2[x] ** 2 for x in list(vec2.keys())])
    denominator = math.sqrt(sum1) * math.sqrt(sum2)

    if not denominator:
        return 0.0
    else:
        return float(numerator) / denominator


def text_to_vector(text):
    words = WORD.findall(text)
    return Counter(words)

# %%
import difflib
def gettext(text):
    #text="અજાણ્યું"
    length = len(text);
    #print(length)
    n=2
    temp = 0;  
    chars = int(length/n);
    #print(chars)
#     #Stores the array of string  
#     equalStr = [];   
#     #Check whether a string can be divided into n equal parts  
#     if(length % n != 0):  
#             #print("Sorry this string cannot be divided into " + str(n) +" equal parts.");  
#             for i in range(0, length, chars):  
#             #Dividing string in n equal part using substring()  
#                 part = text[ i : i+chars];  
#                 equalStr.append(part);  
#             #print("Equal parts of given string are");  
#             #for i in equalStr:  
#                 #print("from odd",i);
#     else:  
#         for i in range(0, length, chars):  
#             #Dividing string in n equal part using substring()  
#             part = text[ i : i+chars];  
#             equalStr.append(part);  
        #print("Equal parts of given string are");  
#         for i in equalStr:  
#             print(i);
#     print(text[0:chars])
#     print(text[-chars:])
    temp = list(text)
    #print("this is temp",temp)
    temp[:chars] = text[-chars:]
    #print("first temp",temp)
#     if(length % n != 0): 
#         temp[chars:] = text[0:chars]
#         #print("second temp",temp)
#     if(length % n == 0):
#         temp[chars:] = text[0:chars]
        #print("second temp",temp)
    temp[chars:] = text[0:chars]
    #print("second temp",temp)
    str8 = "".join(temp)
    #print("this is str8",str8)
    vector1 = text_to_vector(text)
    vector2 = text_to_vector(str8)
    val = get_cosine(vector1, vector2)
#     seq=difflib.SequenceMatcher(None, text,str8)
#     val=seq.ratio()*100
    return val

# %%
from rouge.rouge import rouge_n_sentence_level
from rouge import rouge_n_summary_level
from rouge import rouge_l_summary_level
from rouge import rouge_w_sentence_level
from rouge import rouge_w_summary_level
import os
from urllib.parse import urlparse
def comparerouge1(reference,originalfull_str,filename):
    a = urlparse(filename)
    tokenize_words=[]
    tokenize_words1=[]
    for tokenize in indic_tokenize.trivial_tokenize(originalfull_str):
            tokenize_words.append(tokenize)
    sentences=sentence_tokenize.sentence_split(originalfull_str, lang='gu')
    with codecs.open(reference+os.path.basename(a.path), encoding='utf-8') as f1:
        data1 = f1.read()
    for tokenize1 in indic_tokenize.trivial_tokenize(data1):
            tokenize_words1.append(tokenize1)
        # Convert list of strings to string
    originalfull_str1 = convert_list_to_string(tokenize_words1)
    sentences1=sentence_tokenize.sentence_split(originalfull_str1, lang='gu')
    _, _, rouge_1 = rouge_n_summary_level(tokenize_words, tokenize_words1, 1)
    #rouge1.append(rouge_1)
    #print('ROUGE-1: %f' % rouge_1)
    _, _, rouge_2 = rouge_n_summary_level(tokenize_words, tokenize_words1, 2)
    #print('ROUGE-2: %f' % rouge_2)
    #rouge2.append(rouge_2)
    _, _, rouge_l = rouge_l_summary_level(tokenize_words, tokenize_words1)
    #print('ROUGE-L: %f' % rouge_l)
    #rougel.append(rouge_l)
    _, _, rouge_w = rouge_w_summary_level(tokenize_words, tokenize_words1)
    #avg=(rouge_1+rouge_2+rouge_l+rouge_w)/4
    tokenize_words.clear()
    tokenize_words1.clear()
    return rouge_1

# %%
def comparerouge2(reference,originalfull_str,filename):
    a = urlparse(filename)
    tokenize_words=[]
    tokenize_words1=[]
    for tokenize in indic_tokenize.trivial_tokenize(originalfull_str):
            tokenize_words.append(tokenize)
    sentences=sentence_tokenize.sentence_split(originalfull_str, lang='gu')
    with codecs.open(reference+os.path.basename(a.path), encoding='utf-8') as f1:
        data1 = f1.read()
    for tokenize1 in indic_tokenize.trivial_tokenize(data1):
            tokenize_words1.append(tokenize1)
        # Convert list of strings to string
    originalfull_str1 = convert_list_to_string(tokenize_words1)
    sentences1=sentence_tokenize.sentence_split(originalfull_str1, lang='gu')
   
    _, _, rouge_2 = rouge_n_summary_level(tokenize_words, tokenize_words1, 2)
   
    tokenize_words.clear()
    tokenize_words1.clear()
    return rouge_2

# %%
def comparerougel(reference,originalfull_str,filename):
    a = urlparse(filename)
    tokenize_words=[]
    tokenize_words1=[]
    for tokenize in indic_tokenize.trivial_tokenize(originalfull_str):
            tokenize_words.append(tokenize)
    sentences=sentence_tokenize.sentence_split(originalfull_str, lang='gu')
    with codecs.open(reference+os.path.basename(a.path), encoding='utf-8') as f1:
        data1 = f1.read()
    for tokenize1 in indic_tokenize.trivial_tokenize(data1):
            tokenize_words1.append(tokenize1)
        # Convert list of strings to string
    originalfull_str1 = convert_list_to_string(tokenize_words1)
    sentences1=sentence_tokenize.sentence_split(originalfull_str1, lang='gu')
    
    _, _, rouge_l = rouge_l_summary_level(tokenize_words, tokenize_words1)
    
    tokenize_words.clear()
    tokenize_words1.clear()
    return rouge_l

# %%
def comparerougew(reference,originalfull_str,filename):
    a = urlparse(filename)
    tokenize_words=[]
    tokenize_words1=[]
    for tokenize in indic_tokenize.trivial_tokenize(originalfull_str):
            tokenize_words.append(tokenize)
    sentences=sentence_tokenize.sentence_split(originalfull_str, lang='gu')
    with codecs.open(reference+os.path.basename(a.path), encoding='utf-8') as f1:
        data1 = f1.read()
    for tokenize1 in indic_tokenize.trivial_tokenize(data1):
            tokenize_words1.append(tokenize1)
        # Convert list of strings to string
    originalfull_str1 = convert_list_to_string(tokenize_words1)
    sentences1=sentence_tokenize.sentence_split(originalfull_str1, lang='gu')
    _, _, rouge_w = rouge_w_summary_level(tokenize_words, tokenize_words1)
    
    tokenize_words.clear()
    tokenize_words1.clear()
    return rouge_w

# %%
from nltk.translate.bleu_score import sentence_bleu
def compareblue(reference,originalfull_str,filename):
#def compareblue(reference,originalfull_str):
    refli=[]
    a = urlparse(filename)
    tokenize_words=[]
    tokenize_words1=[]
    for tokenize in indic_tokenize.trivial_tokenize(originalfull_str):
            tokenize_words.append(tokenize)
    #print("tokenize words",tokenize_words)
    #sentences=sentence_tokenize.sentence_split(originalfull_str, lang='gu')
    with codecs.open(reference+os.path.basename(a.path), encoding='utf-8') as f1:
        data1 = f1.read()
    for tokenize1 in indic_tokenize.trivial_tokenize(data1):
            tokenize_words1.append(tokenize1)
    for tokenize1 in indic_tokenize.trivial_tokenize(reference):
        tokenize_words1.append(tokenize1)
        # Convert list of strings to string
    originalfull_str1 = convert_list_to_string(tokenize_words1)
    sentences1=sentence_tokenize.sentence_split(originalfull_str1, lang='gu')
    refli.append(tokenize_words1)
    #print("refli",refli)
    bluescorecard = sentence_bleu(refli,tokenize_words)
    #_, _, rouge_w = rouge_w_summary_level(tokenize_words, tokenize_words1)
    refli.clear()
    tokenize_words.clear()
    tokenize_words1.clear()
    return bluescorecard    
    
# # prefect match
# from nltk.translate.bleu_score import sentence_bleu
# reference = [['પેટ્રોલ-ડીઝલની', 'નવી', 'કિંમતો','જાહેર','થઈ']]
# candidate = ['પેટ્રોલ-ડીઝલની', 'નવી', 'કિંમતો','જાહેર','થઈ']
# score = sentence_bleu(reference, candidate)
# print(score)

# %%
# compareblue("Hello how are you","hello i am fine.")

# %%
import codecs
import string
import re
from bs4 import BeautifulSoup  
from nltk.tokenize import word_tokenize
from indicnlp.tokenize import sentence_tokenize
from indicnlp.tokenize import indic_tokenize
import pandas as pd
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from collections import Counter
from math import log
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import LatentDirichletAllocation  

rouge1=[]
rouge2=[]
rougel=[]
rougew=[]
bluescore=[]

def load_file(filename,createfile):
    file1 = open(createfile, "w", encoding="utf-8")
    with codecs.open(filename, encoding='utf-8') as f:
        data = f.read()
#     soup = BeautifulSoup(data)
#     docno=soup.find_all('docno')
#     titleno = soup.find_all('title')
#     text=soup.find_all('text')
    text=data
    tit=str(text)
    #sentences=sentence_tokenize.sentence_split(text, lang='gu')
    #final_df = pd.DataFrame(columns=['sentence', 'count'])
    senlist=[]
    countlist=[]
#     for n,tit,maintitle in zip(docno,text,titleno):
#         tit=tit.get_text()
#         tit=str(tit)
    sentences=sentence_tokenize.sentence_split(tit, lang='gu')
    for t in sentences:
        count=0
        sen=removestopwords(t)
        if(len(sen)!=0):
            querywords = sen.split()
            #print(querywords)
            j = len(querywords)
            #print("this is j",j)
            while(j>0):
                    j=j-1
                    #print("value of j",j)
                    #print("we are passing",querywords[j])
                    val=gettext(querywords[j])
                    if(val>=0.20):
                        count=count+1
            senlist.append(t)
            countlist.append(count)
        #print(senlist)
        #print(countlist)
        columns=['sentence','count']   
        df = pd.DataFrame(list(zip(senlist, countlist)),
                 columns=columns)
        #final_df = final_df.append({'sentence': senlist, 'count': countlist},ignore_index='True')
        df.sort_values(by=['count'], inplace=True, ascending=False)
        #print(df)
        compressionratio = round((len(df.index)*20)/100)
        final_df2=df['sentence'].head(compressionratio)
        listtoretrieve=list(final_df2.index.values)
        listtoretrieve.sort()
        originalsen=[]
        for t in sentences:  
            originalsen.append(t)
        df4 = pd.DataFrame(originalsen,columns=['sentences'])
        finaldraft=""
        for i in listtoretrieve:
            finaldraft+=df4['sentences'].loc[i]
        rouge_1=comparerouge1("C:/Users/harsh/Downloads/BBC News Summary/BBC News Summary/BBC News Summary/Summaries/tech/",finaldraft,filename)
        rouge_2=comparerouge2("C:/Users/harsh/Downloads/BBC News Summary/BBC News Summary/BBC News Summary/Summaries/tech/",finaldraft,filename)
        rouge_l=comparerougel("C:/Users/harsh/Downloads/BBC News Summary/BBC News Summary/BBC News Summary/Summaries/tech/",finaldraft,filename)
        rouge_w=comparerougew("C:/Users/harsh/Downloads/BBC News Summary/BBC News Summary/BBC News Summary/Summaries/tech/",finaldraft,filename)
        blue=compareblue("C:/Users/harsh/Downloads/BBC News Summary/BBC News Summary/BBC News Summary/Summaries/tech/",finaldraft,filename)
        
        rouge1.append(rouge_1)
        rouge2.append(rouge_2)
        rougel.append(rouge_l)
        rougew.append(rouge_w)
        bluescore.append(blue)
        
        rouge1average=Average(rouge1)
        rouge2average=Average(rouge2)
        rougelaverage=Average(rougel)
        rougewaverage=Average(rougew)
        blueaverage = Average(bluescore)
        
        print("rouge1 average",rouge1average)
        print("rouge2 average",rouge2average)
        print("rougel average",rougelaverage)
        print("rougew average",rougewaverage)
        print("Blue Average",blueaverage)
        file1.write(finaldraft)

# %%
import os

#for root, dirs, files in os.walk("/home/harsh/Documents/gujdocs/gsf2003/"):
for root, dirs, files in os.walk("C:/Users/harsh/Downloads/BBC News Summary/BBC News Summary/BBC News Summary/News Articles/tech"):    
    for file in files:
        if file.endswith('.txt'):
            with open(os.path.join(root, file), 'r') as f:
                file_name=os.path.basename(os.path.join(root, file))
                num=int(os.path.splitext(file_name)[0])
                #load_file(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/entertainment/" + file)
                if num%4==1:
                    thread1 = threading.Thread(target=load_file,
                                            args=(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/tech/" + file))
                    thread1.start()
                    thread1.join()
                if num%4==2:
                    thread2 = threading.Thread(target=load_file,
                                           args=(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/tech/" + file))

                    thread2.start()
                    thread2.join()
                if num%4==3:
                    thread3 = threading.Thread(target=load_file,
                                        args=(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/tech/" + file))

                    thread3.start()
                    thread3.join()
                if num%4==0:
                    thread4 = threading.Thread(target=load_file,
                                        args=(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/tech/" + file))

                    thread4.start()
                    thread4.join()
                #print(os.path.join(root, file))
                #load_file(os.path.join(root, file),"G:/Movies/gujarati Text summarization_lda/religious/"+file)
# Out:
# rouge1 average 0.0
# rouge2 average 0.0
# rougel average 0.0
# rougew average 0.0
# Blue Average 0
# rouge1 average 0.0
# rouge2 average 0.0
# rougel average 0.0
# rougew average 0.0
# Blue Average 0
# rouge1 average 0.08131093134204521
# rouge2 average 0.0801661474558671
# rougel average 0.08131093134204521
# rougew average 0.026657827199440945
# Blue Average 0.0001827285424588641
# rouge1 average 0.12196639701306783
# rouge2 average 0.12024922118380064
# rougel average 0.12196639701306783
# rougew average 0.03998674079916142
# Blue Average 0.00027409281368829614
# rouge1 average 0.1463596764156814
# rouge2 average 0.14429906542056078
# rougel average 0.1463596764156814
# rougew average 0.0479840889589937
# Blue Average 0.0003289113764259554
# rouge1 average 0.16262186268409043
# rouge2 average 0.1603322949117342
# rougel average 0.16262186268409043
# rougew average 0.05331565439888189
# Blue Average 0.0003654570849177282
# rouge1 average 0.17423771001866833
# rouge2 average 0.1717846016911438
# rougel average 0.17423771001866833
# rougew average 0.05712391542737345
# Blue Average 0.0003915611624118516
# rouge1 average 0.19483586560123767
# rouge2 average 0.19067687709848977
# rougel average 0.19483586560123767
# rougew average 0.06394819897693847
# Blue Average 0.0009032893758992148
# rouge1 average 0.21085665327656938
# rouge2 average 0.20537086908198107
# rougel average 0.21085665327656938
# rougew average 0.0692559750710446
# Blue Average 0.0013013002086116083
# rouge1 average 0.22367328341683476
# rouge2 average 0.21712606266877413
# rougel average 0.22367328341683476
# rougew average 0.07350219594632951
# Blue Average 0.0016197088747815231
# rouge1 average 0.23415961716796097
# rouge2 average 0.22674394833069572
# rougel average 0.23415961716796097
# rougew average 0.0769763766624717
# Blue Average 0.0018802250561932717
# rouge1 average 0.24289822862723282
# rouge2 average 0.2347588530489637
# rougel average 0.24289822862723282
# rougew average 0.07987152725925685
# Blue Average 0.0020973218740363954
# rouge1 average 0.26320438849270006
# rouge2 average 0.254184182475445
# rougel average 0.26320438849270006
# rougew average 0.08627932004121715
# Blue Average 0.007190948214239377
# rouge1 average 0.28060966837738627
# rouge2 average 0.2708344648410004
# rougel average 0.28060966837738627
# rougew average 0.09177171385432598
# Blue Average 0.011556913648699076
# rouge1 average 0.2895428065904294
# rouge2 average 0.27932551551639223
# rougel average 0.2895428065904294
# rougew average 0.09440635076384794
# Blue Average 0.012099828400206663
# rouge1 average 0.2973593025268422
# rouge2 average 0.2867551848573601
# rougel average 0.2973593025268422
# rougew average 0.09671165805967966
# Blue Average 0.012574878807775802
# rouge1 average 0.30468375531938086
# rouge2 average 0.29348236918550097
# rougel average 0.30468375531938086
# rougew average 0.09892548392006291
# Blue Average 0.013602241559284379
# rouge1 average 0.3139396174742028
# rouge2 average 0.30248509608420954
# rougel average 0.3139396174742028
# rougew average 0.10181276578332804
# Blue Average 0.015468041438981532
# rouge1 average 0.32600110596569726
# rouge2 average 0.3145806037430442
# rougel average 0.32600110596569726
# rougew average 0.10544267594638411
# Blue Average 0.020581275677911404
# rouge1 average 0.33530695161577906
# rouge2 average 0.32290220646728435
# rougel average 0.33530695161577906
# rougew average 0.1084405670862244
# Blue Average 0.021845168726106885
# rouge1 average 0.34335082676787176
# rouge2 average 0.33030242893583645
# rougel average 0.34335082676787176
# rougew average 0.11125028843829103
# Blue Average 0.02421443793731596
# rouge1 average 0.3507479654231364
# rouge2 average 0.3374017042790478
# rougel average 0.3507479654231364
# rougew average 0.11365046913117392
# Blue Average 0.026394203061563083
# rouge1 average 0.3611552203072767
# rouge2 average 0.3477195712094441
# rougel average 0.3611552203072767
# rougew average 0.11715608917113116
# Blue Average 0.03255555901251355
# rouge1 average 0.3699045544822372
# rouge2 average 0.3562925836693986
# rougel average 0.3699045544822372
# rougew average 0.12023173554880803
# Blue Average 0.03644011412920317
# rouge1 average 0.37992517738355347
# rouge2 average 0.36531716394120456
# rougel average 0.37992517738355347
# rougew average 0.12337971060370019
# Blue Average 0.03915420707404219
# rouge1 average 0.38609302656873784
# rouge2 average 0.37059670822840746
# rougel average 0.38609302656873784
# rougew average 0.12524700407216482
# Blue Average 0.03993973491016778
# rouge1 average 0.3921541585381768
# rouge2 average 0.3755795512653506
# rougel average 0.3921541585381768
# rougew average 0.12716265747139008
# Blue Average 0.04090915710151983
# rouge1 average 0.39756219446602026
# rouge2 average 0.37916577460776185
# rougel average 0.39756219446602026
# rougew average 0.1288718178344186
# Blue Average 0.040503174118811575
# rouge1 average 0.40365685344256763
# rouge2 average 0.3834107233783951
# rougel average 0.40365685344256763
# rougew average 0.13082286382840497
# Blue Average 0.04050315888806548
# rouge1 average 0.4088220803121851
# rouge2 average 0.3884194815787071
# rougel average 0.4088220803121851
# rougew average 0.13267119353828552
# Blue Average 0.043551759476372055
# rouge1 average 0.4134489196040712
# rouge2 average 0.3928956107916355
# rougel average 0.4134489196040712
# rougew average 0.13419794352648148
# Blue Average 0.04618259573289167
# rouge1 average 0.4181315895192147
# rouge2 average 0.39718886977373535
# rougel average 0.4181315895192147
# rougew average 0.13580040928637638
# Blue Average 0.0477400018812243
# rouge1 average 0.40546093529135974
# rouge2 average 0.3851528434169555
# rougel average 0.40546093529135974
# rougew average 0.1316852453686074
# Blue Average 0.04629333515755083
# rouge1 average 0.3935356136651432
# rouge2 average 0.3738248186105744
# rougel average 0.3935356136651432
# rougew average 0.12781214991658954
# Blue Average 0.0449317664764464
# rouge1 average 0.39014139806100695
# rouge2 average 0.37074537638522814
# rougel average 0.39014139806100695
# rougew average 0.12697810134323184
# Blue Average 0.043672125670311306
# rouge1 average 0.3869357499904338
# rouge2 average 0.3678370142835122
# rougel average 0.3869357499904338
# rougew average 0.12619038880172734
# Blue Average 0.042482464908961494
# rouge1 average 0.3839033801939456
# rouge2 average 0.36508586094405115
# rougel average 0.3839033801939456
# rougew average 0.1254452553165204
# Blue Average 0.041357110134711675
# rouge1 average 0.381030608807799
# rouge2 average 0.36247950514877225
# rougel average 0.381030608807799
# rougew average 0.12473933938316643
# Blue Average 0.04029098455910658
# rouge1 average 0.37830515903119827
# rouge2 average 0.36000680862504614
# rougel average 0.37830515903119827
# rougew average 0.12406962426690755
# Blue Average 0.03927953208994278
# rouge1 average 0.3800922999298953
# rouge2 average 0.3620653386190636
# rougel average 0.3800922999298953
# rougew average 0.12522936290333986
# Blue Average 0.03911794736088775
# rouge1 average 0.38179226322377785
# rouge2 average 0.3640234525158119
# rougel average 0.38179226322377785
# rougew average 0.12633252892336083
# Blue Average 0.03896424481373784
# rouge1 average 0.3834112758846184
# rouge2 average 0.36588832289366746
# rougel average 0.3834112758846184
# rougew average 0.12738316322814272
# Blue Average 0.03881786143549984
# rouge1 average 0.38495498563100117
# rouge2 average 0.3676664551144134
# rougel average 0.38495498563100117
# rougew average 0.12838493082107427
# Blue Average 0.0386782865864822
# rouge1 average 0.3864285267525484
# rouge2 average 0.3693637631433073
# rougel average 0.3864285267525484
# rougew average 0.12934116352341804
# Blue Average 0.038545056048783555
# rouge1 average 0.3918763138773456
# rouge2 average 0.3738188514780197
# rougel average 0.3918763138773456
# rougew average 0.13144561899874163
# Blue Average 0.04026630040834393
# rouge1 average 0.397087240692369
# rouge2 average 0.37808024031991855
# rougel average 0.397087240692369
# rougew average 0.1334585764099207
# Blue Average 0.041912708056619084
# rouge1 average 0.4020764259407956
# rouge2 average 0.3821602934664174
# rougel average 0.4020764259407956
# rougew average 0.13538587605892197
# Blue Average 0.04348905580496763
# rouge1 average 0.4068577284705378
# rouge2 average 0.3860703443984788
# rougel average 0.4068577284705378
# rougew average 0.13723287155588149
# Blue Average 0.04499972239713499
# rouge1 average 0.4111221412260038
# rouge2 average 0.3892227973809699
# rougel average 0.4111221412260038
# rougew average 0.13880250433832067
# Blue Average 0.04543343758818022
# rouge1 average 0.417222390377325
# rouge2 average 0.39440290495971175
# rougel average 0.417222390377325
# rougew average 0.14097297059515088
# Blue Average 0.04889051604371641
# rouge1 average 0.4223574633328894
# rouge2 average 0.39941548571731555
# rougel average 0.4223574633328894
# rougew average 0.14273969646990095
# Blue Average 0.0521591153532603
# rouge1 average 0.41423520442264156
# rouge2 average 0.39173441868429026
# rougel average 0.41423520442264156
# rougew average 0.13999470230701824
# Blue Average 0.05115605544262068
# rouge1 average 0.40641944584862943
# rouge2 average 0.3843432032374169
# rougel average 0.40641944584862943
# rougew average 0.13735329282952732
# Blue Average 0.05019084684936369
# rouge1 average 0.4074731683944041
# rouge2 average 0.3852647833095348
# rougel average 0.4074016683229041
# rougew average 0.13845347971881072
# Blue Average 0.04955324941241271
# rouge1 average 0.4084885737566961
# rouge2 average 0.3861528513790302
# rougel average 0.408348173616296
# rougew average 0.13951365981212016
# Blue Average 0.04893883733680541
# rouge1 average 0.4094677146417634
# rouge2 average 0.38700920273175793
# rougel average 0.4092608751492096
# rougew average 0.14053597633066855
# Blue Average 0.048346368549612655
# rouge1 average 0.410412499706302
# rouge2 average 0.38783550666860045
# rougel average 0.4101415520669333
# rougew average 0.14152242209418014
# Blue Average 0.047774688140917884
# rouge1 average 0.4113247059755117
# rouge2 average 0.38863331736624157
# rougel average 0.4109918608150803
# rougew average 0.14247485248653619
# Blue Average 0.04722272084976432
# rouge1 average 0.41594698363606036
# rouge2 average 0.39124095029445305
# rougel average 0.4156197799190261
# rougew average 0.14432798071278338
# Blue Average 0.04801120345650051
# rouge1 average 0.4204151853745907
# rouge2 average 0.3937616621250575
# rougel average 0.42009343505284036
# rougew average 0.14611933799815569
# Blue Average 0.04877340330967883
# rouge1 average 0.42473688869546433
# rouge2 average 0.39619972766613387
# rougel average 0.42442041296915256
# rougew average 0.14785196225777805
# Blue Average 0.04951061300373655
# rouge1 average 0.41788629371650526
# rouge2 average 0.38980940947797044
# rougel average 0.417574922437392
# rougew average 0.14546725318910422
# Blue Average 0.04871205472948273
# rouge1 average 0.4112531779432274
# rouge2 average 0.38362195853387565
# rougel average 0.41094674906536993
# rougew average 0.14315824917022954
# Blue Average 0.04793884751155444
# rouge1 average 0.4088484867437468
# rouge2 average 0.3813398820063695
# rougel average 0.4085468458171059
# rougew average 0.1420964655212389
# Blue Average 0.047236548556931705
# rouge1 average 0.40651778604271177
# rouge2 average 0.3791280232181712
# rougel average 0.40622078574571147
# rougew average 0.14106735213837104
# Blue Average 0.04655585880091275
# rouge1 average 0.4042577126356475
# rouge2 average 0.3769831904538577
# rougel average 0.40396521234314725
# rougew average 0.14006942400952946
# Blue Average 0.0458957960071974
# rouge1 average 0.4020651041064061
# rouge2 average 0.3749023825481804
# rougel average 0.40177696948991326
# rougew average 0.1391012847800563
# Blue Average 0.04525543658045863
# rouge1 average 0.3999369840633188
# rouge2 average 0.3728827748750231
# rougel average 0.3996530867205979
# rougew average 0.13816162023380293
# Blue Average 0.04463391125450629
# rouge1 average 0.3998304531659993
# rouge2 average 0.3725664281713369
# rougel average 0.3995506702775207
# rougew average 0.13816810069013064
# Blue Average 0.04426890938151945
# rouge1 average 0.3997269660086032
# rouge2 average 0.37225911994489885
# rougel average 0.39945118001853147
# rougew average 0.13817439599056325
# Blue Average 0.04391433613347509
# rouge1 average 0.39962639398240135
# rouge2 average 0.37196046828821966
# rougel average 0.399354492302049
# rougew average 0.1381805139585893
# Blue Average 0.04356975086424888
# rouge1 average 0.39952861562359404
# rouge2 average 0.37167011251089266
# rougel average 0.3992604903554688
# rougew average 0.1381864619830591
# Blue Average 0.043234737408056736
# rouge1 average 0.3994335161239321
# rouge2 average 0.37138771168636914
# rougel average 0.39916906380468525
# rougew average 0.13819224704795435
# Blue Average 0.04290890240271916
# rouge1 average 0.40139552841454507
# rouge2 average 0.373099906733161
# rougel average 0.401134649775288
# rougew average 0.13887367044097795
# Blue Average 0.043677471821501106
# rouge1 average 0.40330522037740835
# rouge2 average 0.3747664432453718
# rougel average 0.40304782012000806
# rougew average 0.13953692254352093
# Blue Average 0.04442554605578219
# rouge1 average 0.4051646572886173
# rouge2 average 0.376389123533577
# rougel average 0.40491064387670916
# rougew average 0.1401827206433654
# Blue Average 0.04515393412600325
# rouge1 average 0.4069757971371975
# rouge2 average 0.3779696562818288
# rougel average 0.4067250826007687
# rougew average 0.14081174476659056
# Blue Average 0.04586340302556922
# rouge1 average 0.4090979263827078
# rouge2 average 0.3798187265949759
# rougel average 0.40885042613520756
# rougew average 0.14169132670632034
# Blue Average 0.04678718558406618
# rouge1 average 0.41138624725290635
# rouge2 average 0.3813539595594216
# rougel average 0.4111418799199314
# rougew average 0.14260701700713352
# Blue Average 0.04719854665953126
# rouge1 average 0.4144835537370869
# rouge2 average 0.3840993503358648
# rougel average 0.41424224099577417
# rougew average 0.14375205901953983
# Blue Average 0.04887372818985437
# rouge1 average 0.4093664728267525
# rouge2 average 0.37935738304776767
# rougel average 0.40912813925508557
# rougew average 0.14197734224152084
# Blue Average 0.04827034882948579
# rouge1 average 0.40437419876788966
# rouge2 average 0.3747310734984047
# rougel average 0.4041387717031943
# rougew average 0.14024591123857547
# Blue Average 0.04768168603888231
# rouge1 average 0.4012242887111491
# rouge2 average 0.37190235912708475
# rougel average 0.4009916981171127
# rougew average 0.1391421886337644
# Blue Average 0.04710722674423561
# rouge1 average 0.3981493765129024
# rouge2 average 0.36914099509793913
# rougel average 0.3979195548545093
# rougew average 0.1380647451385917
# Blue Average 0.04654644505184242
# rouge1 average 0.3951468151899085
# rouge2 average 0.3664446043400675
# rougel average 0.39491969731573184
# rougew average 0.13701265325507014
# Blue Average 0.04599885822279964
# rouge1 average 0.39221408087442616
# rouge2 average 0.3638109203440068
# rougel average 0.39198960390576315
# rougew average 0.13598502862465373
# Blue Average 0.045464005971176474
# rouge1 average 0.38934876573861005
# rouge2 average 0.36123778080762575
# rougel average 0.38912686896498916
# rougew average 0.13498102754895955
# Blue Average 0.044941449173613604
# rouge1 average 0.3873825807498769
# rouge2 average 0.3594454057067416
# rougel average 0.3871632055305017
# rougew average 0.1342026940588785
# Blue Average 0.044432623677777665
# rouge1 average 0.3854605796934749
# rouge2 average 0.35769330869801225
# rougel average 0.385243669364205
# rougew average 0.133441851209024
# Blue Average 0.04393523246274702
# rouge1 average 0.38358128977165956
# rouge2 average 0.3559801471783657
# rougel average 0.38336678955715936
# rougew average 0.13269791597805514
# Blue Average 0.04344889438582817
# rouge1 average 0.3823814529089567
# rouge2 average 0.35481021634130455
# rougel average 0.3821693098396708
# rougew average 0.13226201671273644
# Blue Average 0.04299636468845472
# rouge1 average 0.3812076994563126
# rouge2 average 0.35366571878331
# rougel average 0.3809978622899537
# rougew average 0.13183559351840296
# Blue Average 0.04255367259319809
# rouge1 average 0.3807395996622087
# rouge2 average 0.35313672475061864
# rougel average 0.3805320188094666
# rougew average 0.13163684322931304
# Blue Average 0.04216482646563427
# rouge1 average 0.3802814594381922
# rouge2 average 0.35261898591011226
# rougel average 0.3800760868923941
# rougew average 0.13144232166977826
# Blue Average 0.04178425365993352
# rouge1 average 0.3798329642715233
# rouge2 average 0.3521121468346691
# rougel average 0.3796297535419968
# rougew average 0.1312518953009705
# Blue Average 0.041411692913300144
# rouge1 average 0.37939381275416006
# rouge2 average 0.3516158669066311
# rougel average 0.3791927188030661
# rougew average 0.1310654361481796
# Blue Average 0.0410468938488883
# rouge1 average 0.3795133712926841
# rouge2 average 0.3517651423158931
# rougel average 0.3793143504751066
# rougew average 0.1310125808345819
# Blue Average 0.040859181567505114
# rouge1 average 0.38005166903213505
# rouge2 average 0.3521248025708478
# rougel average 0.3798546790392267
# rougew average 0.13103976472276707
# Blue Average 0.04066100346079411
# rouge1 average 0.38075559191728564
# rouge2 average 0.3526592020963352
# rougel average 0.38056059172228546
# rougew average 0.13108711132521358
# Blue Average 0.040515157300464656
# rouge1 average 0.3804045979204788
# rouge2 average 0.3521760883362414
# rougel average 0.3802115477274286
# rougew average 0.13089869905436316
# Blue Average 0.040201550592883335
# rouge1 average 0.3811711991816741
# rouge2 average 0.3527229330795203
# rougel average 0.3809800603766739
# rougew average 0.130962817133996
# Blue Average 0.04014421019918525
# rouge1 average 0.38210751240960744
# rouge2 average 0.35338450957035156
# rougel average 0.3819182475144602
# rougew average 0.1311040585691736
# Blue Average 0.04004587176572012
# rouge1 average 0.3838935352432176
# rouge2 average 0.35488747716475444
# rougel average 0.3837061078713242
# rougew average 0.13152961507938396
# Blue Average 0.040549950323175106
# rouge1 average 0.38563853827414646
# rouge2 average 0.3562539321873992
# rougel average 0.38545291308852125
# rougew average 0.13201476205779833
# Blue Average 0.04067166491654361
# rouge1 average 0.3871367403561847
# rouge2 average 0.3573410128780332
# rougel average 0.3869528830294703
# rougew average 0.1324197770982779
# Blue Average 0.04071182082735862
# rouge1 average 0.3887844857566829
# rouge2 average 0.35875883843662115
# rougel average 0.38860236293305067
# rougew average 0.13279657418447136
# Blue Average 0.041053987339657476
# rouge1 average 0.39007548585330604
# rouge2 average 0.3597962841389804
# rougel average 0.3898950651121376
# rougew average 0.1330349356859627
# Blue Average 0.041075858527396016
# rouge1 average 0.39140396797344346
# rouge2 average 0.36097692490904065
# rougel average 0.39122521779469327
# rougew average 0.13333729000701125
# Blue Average 0.041574520753159795
# rouge1 average 0.3921859087628494
# rouge2 average 0.36163606439842283
# rougel average 0.392008798493996
# rougew average 0.13348807246841915
# Blue Average 0.041829694883096694
# rouge1 average 0.39341742415039505
# rouge2 average 0.36264232493341203
# rougel average 0.3932419239748949
# rougew average 0.1336900138517182
# Blue Average 0.04204830384924881
# rouge1 average 0.39500883198928805
# rouge2 average 0.364026940576846
# rougel average 0.39483491289645006
# rougew average 0.1340858951901922
# Blue Average 0.04247904522064978
# rouge1 average 0.3960295765902014
# rouge2 average 0.36481660989780895
# rougel average 0.39585721034640653
# rougew average 0.13432692927584372
# Blue Average 0.04248538760683521
# rouge1 average 0.39815550933891625
# rouge2 average 0.3667450565045091
# rougel average 0.39797794131642233
# rougew average 0.13491616201867485
# Blue Average 0.04349247185671389
# rouge1 average 0.4001499962907455
# rouge2 average 0.3684338149675295
# rougel average 0.399973985882484
# rougew average 0.1354796572229015
# Blue Average 0.043869784744264145
# rouge1 average 0.40243953763703827
# rouge2 average 0.3703116654208586
# rougel average 0.402265057754066
# rougew average 0.1361238913068515
# Blue Average 0.044265391285606415
# rouge1 average 0.4047407113871387
# rouge2 average 0.372263054754266
# rougel average 0.4045677356410886
# rougew average 0.13677368646141813
# Blue Average 0.04503995143746365
# rouge1 average 0.40693062136364083
# rouge2 average 0.37407901139207594
# rougel average 0.40675912404277065
# rougew average 0.13737272909937087
# Blue Average 0.04577207620618355
# rouge1 average 0.40348205677581334
# rouge2 average 0.3709088502785837
# rougel average 0.4033120128220692
# rougew average 0.13620855342903723
# Blue Average 0.04538417725528369
# rouge1 average 0.4000914512566889
# rouge2 average 0.36779196918380574
# rougel average 0.3999228362437325
# rougew average 0.13506394373635625
# Blue Average 0.04500279761448298
# rouge1 average 0.3982627948349888
# rouge2 average 0.3660397548937384
# rougel average 0.3980858724374279
# rougew average 0.13446864523077467
# Blue Average 0.04462777430102896
# rouge1 average 0.3964643641392672
# rouge2 average 0.36431650282334166
# rougel average 0.396279271669244
# rougew average 0.13388318636991345
# Blue Average 0.04425894972002872
# rouge1 average 0.39469541591396734
# rouge2 average 0.3626215007868858
# rougel average 0.3945022873070959
# rougew average 0.13330732519529587
# Blue Average 0.04389617144363504
# rouge1 average 0.3929552310744447
# rouge2 average 0.36095405975915285
# rougel average 0.39275419699961694
# rougew average 0.13274082761701353
# Blue Average 0.043539292001003864
# rouge1 average 0.3912431137323337
# rouge2 average 0.35931351294154457
# rougel average 0.3910343016970973
# rougew average 0.1321834670964454
# Blue Average 0.04318816867841512
# rouge1 average 0.3909894790950117
# rouge2 average 0.3591588369471413
# rougel average 0.3907823375560572
# rougew average 0.13209806346332914
# Blue Average 0.042938864878084855
# rouge1 average 0.3907398704043139
# rouge2 average 0.3590066161272523
# rougel average 0.39053437284582726
# rougew average 0.13201401544343694
# Blue Average 0.04269351828093443
# rouge1 average 0.39049419255913886
# rouge2 average 0.35885679248562935
# rougel average 0.39029031309166395
# rougew average 0.13193129101440917
# Blue Average 0.04245203540972338
# rouge1 average 0.3902523534302947
# rouge2 average 0.3587093098384067
# rougel average 0.39005006677115944
# rougew average 0.13184985915458497
# Blue Average 0.04221432570837501
# rouge1 average 0.3900142637453086
# rouge2 average 0.3585641137438542
# rougel average 0.38981354519981
# rougew average 0.1317696898042154
# Blue Average 0.04198030142875297
# rouge1 average 0.3905893459555472
# rouge2 average 0.3591812013643434
# rougel average 0.3903901713988601
# rougew average 0.13195437165535426
# Blue Average 0.04205813527198338
# rouge1 average 0.3911556482847134
# rouge2 average 0.3597888677997869
# rougel average 0.39095799414448956
# rougew average 0.1321362339362467
# Blue Average 0.04213478081226371
# rouge1 average 0.39171337027555886
# rouge2 average 0.36038732716802674
# rougel average 0.39151721351518526
# rougew average 0.13231534072803472
# Blue Average 0.042210265056479186
# rouge1 average 0.3924750650635797
# rouge2 average 0.36123594134005804
# rougel average 0.39228038316606606
# rougew average 0.13250677799306604
# Blue Average 0.04259865956967477
# rouge1 average 0.39322539127267486
# rouge2 average 0.3620718896289247
# rougel average 0.39303216222514264
# rougew average 0.13269535798548496
# Blue Average 0.042981257149837575
# rouge1 average 0.39462383551331875
# rouge2 average 0.3635106857226328
# rougel average 0.3944320377920646
# rougew average 0.13308880755030217
# Blue Average 0.04394214265453365
# rouge1 average 0.3960017143974826
# rouge2 average 0.36492832305025685
# rougel average 0.39581132695359056
# rougew average 0.13347647109210736
# Blue Average 0.044888897490043024
# rouge1 average 0.3973594782614397
# rouge2 average 0.3663252649424412
# rougel average 0.3971704805069191
# rougew average 0.13385847531213438
# Blue Average 0.04582183108707781
# rouge1 average 0.398697564388238
# rouge2 average 0.3677019612999562
# rougel average 0.3985099361826632
# rougew average 0.1342349432391175
# Blue Average 0.046741243907343966
# rouge1 average 0.4000163974772406
# rouge2 average 0.36905884907678754
# rougel average 0.39983011911487143
# rougew average 0.13460599436139586
# Blue Average 0.04764742776616745
# rouge1 average 0.4017270998621828
# rouge2 average 0.37082117807576204
# rougel average 0.40154215205954485
# rougew average 0.13509123049112357
# Blue Average 0.048992086149117944
# rouge1 average 0.4034135369650691
# rouge2 average 0.372558509500283
# rougel average 0.40322990084897464
# rougew average 0.13556958383886933
# Blue Average 0.05031767136351594
# rouge1 average 0.40484233394067504
# rouge2 average 0.3740144220371676
# rougel average 0.4046599910366658
# rougew average 0.13595788283737928
# Blue Average 0.05132194364057033
# rouge1 average 0.40625114774179694
# rouge2 average 0.3754499721609489
# rougel average 0.40607007996299055
# rougew average 0.13634075108066532
# Blue Average 0.05231217015151207
# rouge1 average 0.4080182000748066
# rouge2 average 0.3770856859425444
# rougel average 0.4078383897111308
# rougew average 0.13682425563482373
# Blue Average 0.05350604333349267
# rouge1 average 0.41034439772468034
# rouge2 average 0.37910663744479883
# rougel average 0.41016582743247815
# rougew average 0.13748270949659158
# Blue Average 0.05502919712894197
# rouge1 average 0.4124049425416879
# rouge2 average 0.38109307616960786
# rougel average 0.41222759533367886
# rougew average 0.13809244488998773
# Blue Average 0.056846653446601815
# rouge1 average 0.4095994667420846
# rouge2 average 0.37850060626369214
# rougel average 0.40942332597766745
# rougew average 0.13715304050298102
# Blue Average 0.05645994151839364
# rouge1 average 0.40683190277761105
# rouge2 average 0.3759431697348834
# rougel average 0.406656952153494
# rougew average 0.13622633076985277
# Blue Average 0.05607845542705314
# rouge1 average 0.4067650779267546
# rouge2 average 0.3759657682254385
# rougel average 0.4065913014679001
# rougew average 0.13643062551064739
# Blue Average 0.05573624418322468
# rouge1 average 0.40669914407390956
# rouge2 average 0.3759880654027861
# rougel average 0.4065265261247808
# rougew average 0.13663219632156476
# Blue Average 0.05539859575598059
# rouge1 average 0.4066340835171287
# rouge2 average 0.3760100672532815
# rougel average 0.4064626087332259
# rougew average 0.13683109732041698
# Blue Average 0.05506541949333577
# rouge1 average 0.4065698790203055
# rouge2 average 0.376031779605744
# rougel average 0.40639953235998105
# rougew average 0.13702738120086325
# Blue Average 0.05473662712888364
# rouge1 average 0.40650651379795055
# rouge2 average 0.37605320813660575
# rougel average 0.406337280514491
# rougew average 0.13722109927895076
# Blue Average 0.05441213270383611
# rouge1 average 0.4080178825033516
# rouge2 average 0.3776524757820298
# rougel average 0.40784974813731706
# rougew average 0.137939272274773
# Blue Average 0.05497553217685753
# rouge1 average 0.40950974967707
# rouge2 average 0.3792311077159
# rougel average 0.40934270004888085
# rougew average 0.13864817852226208
# Blue Average 0.055531661979259316
# rouge1 average 0.41098249034856127
# rouge2 average 0.38078950077882323
# rougel average 0.41081651155132204
# rougew average 0.13934799622811667
# Blue Average 0.05608066191239954
# rouge1 average 0.41243646999239025
# rouge2 average 0.3823280417008174
# rougel average 0.41227154838494234
# rougew average 0.14003889905873743
# Blue Average 0.05662266821581823
# rouge1 average 0.4138720448306011
# rouge2 average 0.38384710742126743
# rougel average 0.4137081670307953
# rougew average 0.1407210562839073
# Blue Average 0.057157813679953144
# rouge1 average 0.41584169955746514
# rouge2 average 0.38589181255623173
# rougel average 0.41567885243564556
# rougew average 0.14162026532254945
# Blue Average 0.05843596189257323
# rouge1 average 0.41778673360024343
# rouge2 average 0.38791095887700905
# rougel average 0.4176249042729352
# rougew average 0.14250823424820855
# Blue Average 0.05969813325253557
# rouge1 average 0.41970760572944676
# rouge2 average 0.3899050226347953
# rougel average 0.4195467815532398
# rougew average 0.1433851725039837
# Blue Average 0.06094462546516918
# rouge1 average 0.42160476338791925
# rouge2 average 0.39187446832149775
# rougel average 0.4214449319535407
# rougew average 0.1442512843615394
# Blue Average 0.06217572888505423
# rouge1 average 0.4190182310971958
# rouge2 average 0.3894703304790346
# rougel average 0.4188593802237644
# rougew average 0.14336630715686738
# Blue Average 0.06179428269557537
# rouge1 average 0.4164632418831885
# rouge2 average 0.38709551139074777
# rougel average 0.41630535961264387
# rougew average 0.14249212235713038
# Blue Average 0.06141748828889503
# rouge1 average 0.4156708239670133
# rouge2 average 0.3864689195954617
# rougel average 0.41551389855871446
# rougew average 0.14227869505559465
# Blue Average 0.06105219786798651
# rouge1 average 0.4148879532546475
# rouge2 average 0.38584987709891394
# rougel average 0.41473197318013355
# rougew average 0.14206783916733046
# Blue Average 0.06069130853648653
# rouge1 average 0.41411445823943577
# rouge2 average 0.3852382482849596
# rougel average 0.41395941217734405
# rougew average 0.14185950849928497
# Blue Average 0.0603347412329087
# rouge1 average 0.4133501714982146
# rouge2 average 0.3846339007664095
# rougel average 0.41319604832934964
# rougew average 0.14165365795824003
# Blue Average 0.059982418778182986
# rouge1 average 0.4125949295704991
# rouge2 average 0.384036705289499
# rougel average 0.4124417183730475
# rougew average 0.14145024351827257
# Blue Average 0.0596342658199629
# rouge1 average 0.4131943285355149
# rouge2 average 0.38472596380987273
# rougel average 0.41304201858040124
# rougew average 0.141804976308876
# Blue Average 0.05955858411087275
# rouge1 average 0.41378671698632
# rouge2 average 0.38540716082708415
# rougel average 0.41363529773269825
# rougew average 0.14215556017795195
# Blue Average 0.059483787567970785
# rouge1 average 0.41437221719932504
# rouge2 average 0.3860804369487466
# rougel average 0.4142216782902011
# rougew average 0.14250206749041072
# Blue Average 0.05940986075231187
# rouge1 average 0.41495094862374043
# rouge2 average 0.3867459295314303
# rougel average 0.4148012798817213
# rougew average 0.14284456893798556
# Blue Average 0.05933678858192069
# rouge1 average 0.41552302796281776
# rouge2 average 0.38740377277408317
# rougel average 0.41537421938598257
# rougew average 0.14318313358731244
# Blue Average 0.059264556321534
# rouge1 average 0.41616979999715187
# rouge2 average 0.38813625138666563
# rougel average 0.4160218417550415
# rougew average 0.14354373163671322
# Blue Average 0.05927761369264732
# rouge1 average 0.41680922234927764
# rouge2 average 0.3888604063786506
# rougel average 0.41666210477899746
# rougew average 0.14390023198100718
# Blue Average 0.05929052268454344
# rouge1 average 0.41445436798572244
# rouge2 average 0.38666345493018367
# rougel average 0.4143080815881557
# rougew average 0.14308723632009754
# Blue Average 0.058955547980110996
# rouge1 average 0.4121259726599599
# rouge2 average 0.3844911883294523
# rougel average 0.4119805080960874
# rougew average 0.14228337544189473
# Blue Average 0.058624337036402505
# rouge1 average 0.4102144101161985
# rouge2 average 0.3827272710762151
# rougel average 0.4100697582035208
# rougew average 0.141646266199266
# Blue Average 0.05829682677363202
# rouge1 average 0.40832408715625673
# rouge2 average 0.3809829529035695
# rougel average 0.40818023886531607
# rougew average 0.14101623594822207
# Blue Average 0.057972955513781205
# rouge1 average 0.4064781676681375
# rouge2 average 0.37928489761348244
# rougel average 0.40633511411913575
# rougew average 0.14037873372592413
# Blue Average 0.05765266294194114
# rouge1 average 0.404652533009558
# rouge2 average 0.37760550227163814
# rougel average 0.40451026546906726
# rougew average 0.13974823702255254
# Blue Average 0.05733589006869272
# rouge1 average 0.4028468506423291
# rouge2 average 0.37594446097724565
# rougel average 0.4027053605200924
# rougew average 0.13912463099353473
# Blue Average 0.05702257919405904
# rouge1 average 0.40134340902053933
# rouge2 average 0.3745843446681807
# rougel average 0.40120268786635827
# rougew average 0.13857804487597256
# Blue Average 0.05671269723226315
# rouge1 average 0.3998562208216878
# rouge2 average 0.3732389323192137
# rougel average 0.3997162603223942
# rougew average 0.13803736779751918
# Blue Average 0.05640616534572992
# rouge1 average 0.3983850238937917
# rouge2 average 0.371907986769698
# rougel average 0.3982458158703008
# rougew average 0.1375025044510922
# Blue Average 0.056102929500987365
# rouge1 average 0.3969295616923972
# rouge2 average 0.3705912759319418
# rougel average 0.3967910980968393
# rougew average 0.13697336156826334
# Blue Average 0.05580293682035971
# rouge1 average 0.39548958313144295
# rouge2 average 0.3692885726562894
# rougel average 0.3953518560443721
# rougew average 0.13644984786503905
# Blue Average 0.05550613555122808
# rouge1 average 0.3946453662402098
# rouge2 average 0.36858067468434524
# rougel average 0.3945083678678854
# rougew average 0.13611450374209033
# Blue Average 0.05522305435494043
# rouge1 average 0.3938100358425686
# rouge2 average 0.3678802282700005
# rougel average 0.393673758514309
# rougew average 0.1357826895572779
# Blue Average 0.054942952960718966
# rouge1 average 0.39298345236008586
# rouge2 average 0.36718711637308343
# rougel average 0.3928478885256915
# rougew average 0.1354543498665473
# Blue Average 0.05466578456538987
# rouge1 average 0.3921654791222124
# rouge2 average 0.3665012243917593
# rougel average 0.39203062134945554
# rougew average 0.13512943038092845
# Blue Average 0.05439150334084545
# rouge1 average 0.391355982290949
# rouge2 average 0.36582244009936077
# rougel average 0.39122182326312865
# rougew average 0.13480787793661136
# Blue Average 0.05412006440878336
# rouge1 average 0.39117600765570926
# rouge2 average 0.3656846499477025
# rougel average 0.3910425401692695
# rougew average 0.1346724304490866
# Blue Average 0.05398430731449354
# rouge1 average 0.39042616122360746
# rouge2 average 0.3650604103001794
# rougel average 0.39029337818581605
# rougew average 0.13436883862608046
# Blue Average 0.053721046462743546
# rouge1 average 0.3899161115823404
# rouge2 average 0.3646749495456273
# rougel average 0.3897840060090276
# rougew average 0.13413632396954658
# Blue Average 0.05348775098686848
# rouge1 average 0.38941124011002026
# rouge2 average 0.364293402098228
# rougel average 0.38927980512337396
# rougew average 0.13390616986790138
# Blue Average 0.053256823992982
# rouge1 average 0.3889114683495417
# rouge2 average 0.3639157086654489
# rougel average 0.3887806971759593
# rougew average 0.1336783405551617
# Blue Average 0.053028229594993356
# rouge1 average 0.3887699167777867
# rouge2 average 0.36389539159408973
# rougel average 0.3886398027457801
# rougew average 0.1335575561043883
# Blue Average 0.05289966862934827
# rouge1 average 0.38858466031939737
# rouge2 average 0.36376079866704436
# rougel average 0.38845519685755076
# rougew average 0.13341928885170384
# Blue Average 0.05274041767377615
# rouge1 average 0.3884012472088527
# rouge2 average 0.36362754497310396
# rougel average 0.3882724278438312
# rougew average 0.1332823973925784
# Blue Average 0.05258275130482663
# rouge1 average 0.38797680590221645
# rouge2 average 0.3633102444469596
# rougel average 0.3878486242568238
# rougew average 0.13308220797588807
# Blue Average 0.052370818992035564
# rouge1 average 0.38755654628333036
# rouge2 average 0.36299607003437334
# rougel average 0.3874289960746145
# rougew average 0.13288399086872177
# Blue Average 0.05216097468232618
# rouge1 average 0.387247804813178
# rouge2 average 0.36277935193983046
# rougel average 0.3871208798505833
# rougew average 0.13270693360839106
# Blue Average 0.05198343898591205
# rouge1 average 0.38693320882814664
# rouge2 average 0.3625505510503996
# rougel average 0.38680690301171095
# rougew average 0.13252419381563482
# Blue Average 0.05180148000817764
# rouge1 average 0.3865440440755299
# rouge2 average 0.3622486370258326
# rougel average 0.38641835139412545
# rougew average 0.1323333410931117
# Blue Average 0.05160184340903672
# rouge1 average 0.38619252207733995
# rouge2 average 0.3619862972718156
# rougel average 0.38606743660695675
# rougew average 0.1321479119705633
# Blue Average 0.05141858507099225
# rouge1 average 0.3858879579829794
# rouge2 average 0.36178329165612116
# rougel average 0.38576347388505
# rougew average 0.13196693944178836
# Blue Average 0.051238747749511995
# rouge1 average 0.38550756254308055
# rouge2 average 0.3614770510091322
# rougel average 0.38538367406284463
# rougew average 0.131779926122211
# Blue Average 0.05104447318548822
# rouge1 average 0.3851510366941281
# rouge2 average 0.36119407449758456
# rougel average 0.38502773815903607
# rougew average 0.1316012582029012
# Blue Average 0.05085607843856417
# rouge1 average 0.3847978902371088
# rouge2 average 0.3609137802278526
# rougel average 0.3846751760552637
# rougew average 0.1314242838183716
# Blue Average 0.05066946942383846
# rouge1 average 0.38432639903118276
# rouge2 average 0.36051638818275267
# rougel average 0.384204263689818
# rougew average 0.13120888164869818
# Blue Average 0.050470623603560694
# rouge1 average 0.3840628798336121
# rouge2 average 0.360335008930813
# rougel average 0.38394131789760594
# rougew average 0.13105065783397166
# Blue Average 0.050315383004530374
# rouge1 average 0.3838821258442233
# rouge2 average 0.3602509761587714
# rougel average 0.3837611319546471
# rougew average 0.1309202079527734
# Blue Average 0.05018326820481378
# rouge1 average 0.3837841522198789
# rouge2 average 0.3602391606967692
# rougel average 0.38366372109257973
# rougew average 0.1308207129556472
# Blue Average 0.05007585724577612
# rouge1 average 0.38364513296704067
# rouge2 average 0.3601927443028777
# rougel average 0.3835252593912568
# rougew average 0.13071741652390395
# Blue Average 0.04995363373083291
# rouge1 average 0.3835073949976387
# rouge2 average 0.36014675570985155
# rougel average 0.38338807383464646
# rougew average 0.13061507213300624
# Blue Average 0.04983253669989839
# rouge1 average 0.38343276979910507
# rouge2 average 0.36016320402055785
# rougel average 0.3833139959808972
# rougew average 0.13053247345913688
# Blue Average 0.04973010333459307
# rouge1 average 0.38341357429125467
# rouge2 average 0.3602200186840442
# rougel average 0.38329534281924865
# rougew average 0.13045692252440189
# Blue Average 0.049649474479208984
# rouge1 average 0.3834463534990217
# rouge2 average 0.36032361853279427
# rougel average 0.3833286594427975
# rougew average 0.130420433413883
# Blue Average 0.04957646930089623
# rouge1 average 0.3834788360623745
# rouge2 average 0.3604262808263521
# rougel average 0.38336167455844095
# rougew average 0.13038427452155887
# Blue Average 0.04950412480293019
# rouge1 average 0.3833692520874717
# rouge2 average 0.3603735773751058
# rougel average 0.38325261833806035
# rougew average 0.1302888380854082
# Blue Average 0.04938142452042262
# rouge1 average 0.3831821547867922
# rouge2 average 0.36024710683365996
# rougel average 0.3830660440586786
# rougew average 0.1301664720259952
# Blue Average 0.049244366384146164
# rouge1 average 0.3831655153753544
# rouge2 average 0.3602939473443448
# rougel average 0.38304992299870566
# rougew average 0.13011056021355222
# Blue Average 0.04916079330621314
# rouge1 average 0.38314902386979616
# rouge2 average 0.3603403714949346
# rougel average 0.3830339452370436
# rougew average 0.1300551453949976
# Blue Average 0.04907796310008397
# rouge1 average 0.3835553077193078
# rouge2 average 0.3607634607769163
# rougel average 0.38344073828404535
# rougew average 0.13011326637609724
# Blue Average 0.04917286691948002
# rouge1 average 0.383707089276299
# rouge2 average 0.36096697796874594
# rougel average 0.38359302455220506
# rougew average 0.13010227548506081
# Blue Average 0.049159703634926
# rouge1 average 0.3840546623687322
# rouge2 average 0.3613782033643181
# rougel average 0.3839410979285159
# rougew average 0.13015525396306715
# Blue Average 0.049245333979000945
# rouge1 average 0.3844664169290998
# rouge2 average 0.3618491587285891
# rougel average 0.3843533484034696
# rougew average 0.1302285759679021
# Blue Average 0.04935942627445081
# rouge1 average 0.38478933889553707
# rouge2 average 0.36224972129179694
# rougel average 0.3846767619721922
# rougew average 0.13027165262044274
# Blue Average 0.04946608755450906
# rouge1 average 0.3852754653423311
# rouge2 average 0.36278816845522116
# rougel average 0.3851633757649747
# rougew average 0.13037476725617353
# Blue Average 0.04962305980769672
# rouge1 average 0.38554757852761584
# rouge2 average 0.3631408569815182
# rougel average 0.3854359720949895
# rougew average 0.13040580996186216
# Blue Average 0.04968160189292215
# rouge1 average 0.3858173559774046
# rouge2 average 0.36349051813849087
# rougel average 0.38570622854234315
# rougew average 0.13043658620655774
# Blue Average 0.04973964147097827
# rouge1 average 0.38641584643885624
# rouge2 average 0.3640958047857981
# rougel average 0.38630519390736345
# rougew average 0.13055326374791337
# Blue Average 0.049997921657857367
# rouge1 average 0.3869146234626257
# rouge2 average 0.364564956950146
# rougel average 0.386804441792969
# rougew average 0.13063925953460578
# Blue Average 0.05022188382636373
# rouge1 average 0.3875354435539159
# rouge2 average 0.3651549150410931
# rougel average 0.38742572875574083
# rougew average 0.13076535135091
# Blue Average 0.05054512471956168
# rouge1 average 0.38815102465709395
# rouge2 average 0.3657398945827495
# rougel average 0.38804177279055674
# rougew average 0.13089037910125384
# Blue Average 0.050865637841509014
# rouge1 average 0.38865342374560197
# rouge2 average 0.3662664795522952
# rougel average 0.38854463092052083
# rougew average 0.13097053091097688
# Blue Average 0.05120605948650188
# rouge1 average 0.38924512043591813
# rouge2 average 0.366883248246152
# rougel average 0.3891367828109419
# rougew average 0.13108980055375857
# Blue Average 0.051607402392179896
# rouge1 average 0.3899206368572237
# rouge2 average 0.36757887148694324
# rougel average 0.3898127506390182
# rougew average 0.13122185493745944
# Blue Average 0.052103579159170854
# rouge1 average 0.3905905473331243
# rouge2 average 0.368268721920757
# rougel average 0.3904831087755753
# rougew average 0.13135281343415867
# Blue Average 0.05259563827664321
# rouge1 average 0.3913304363254662
# rouge2 average 0.36905411287700735
# rougel average 0.3912234417288988
# rougew average 0.13151238987473146
# Blue Average 0.053172125903946994
# rouge1 average 0.3920932094074202
# rouge2 average 0.3698471689379241
# rougel average 0.39198665511783454
# rougew average 0.13167335223418938
# Blue Average 0.05371994576598037
# rouge1 average 0.3928751038683548
# rouge2 average 0.3706481114486225
# rougel average 0.3927689862766773
# rougew average 0.1318368942578618
# Blue Average 0.05428657074234124
# rouge1 average 0.39365061551736336
# rouge2 average 0.37144251565311104
# rougel average 0.39354493105871313
# rougew average 0.13199910124460626
# Blue Average 0.054848570208691015
# rouge1 average 0.39431013597775944
# rouge2 average 0.37214591261999824
# rougel average 0.3942048811307297
# rougew average 0.13213142818996018
# Blue Average 0.055340901141067225
# rouge1 average 0.3948170245414293
# rouge2 average 0.37270087474253355
# rougel average 0.3947121958273835
# rougew average 0.13222433523617852
# Blue Average 0.05567927412711728
# rouge1 average 0.3954460674752588
# rouge2 average 0.3733785668195422
# rougel average 0.3953416614576406
# rougew average 0.13234994805596506
# Blue Average 0.05613921364356406
# rouge1 average 0.39611066251575233
# rouge2 average 0.37408424567251536
# rougel average 0.3960066757994097
# rougew average 0.1324830157095239
# Blue Average 0.056636699677219994
# rouge1 average 0.39669398612393625
# rouge2 average 0.37470766352245144
# rougel average 0.396590415354459
# rougew average 0.13260643505891068
# Blue Average 0.05702733143435164
# rouge1 average 0.3972726617352422
# rouge2 average 0.3753261138994796
# rougel average 0.39716950359831266
# rougew average 0.13272887098718683
# Blue Average 0.05741485058784081
# rouge1 average 0.39777726962447224
# rouge2 average 0.375862019929957
# rougel average 0.3976745208452289
# rougew average 0.13282870030133584
# Blue Average 0.057709970531938076
# rouge1 average 0.3982259899473143
# rouge2 average 0.37633936916471367
# rougel average 0.3981236472897281
# rougew average 0.13290240601160835
# Blue Average 0.057964439371440024
# rouge1 average 0.3987763817498605
# rouge2 average 0.37691925152864403
# rougel average 0.398674442016123
# rougew average 0.13301277084739202
# Blue Average 0.05825538891425431
# rouge1 average 0.39932245675395533
# rouge2 average 0.37749458579560236
# rougel average 0.3992209167838796
# rougew average 0.13312227007662053
# Blue Average 0.058544056499870045
# rouge1 average 0.3997444577598042
# rouge2 average 0.3779406097531917
# rougel average 0.3996433144302366
# rougew average 0.1331969283763136
# Blue Average 0.05871155354228014
# rouge1 average 0.400309425536889
# rouge2 average 0.3784998184719373
# rougel average 0.4002086757611329
# rougew average 0.13331440290773286
# Blue Average 0.05894447143840204
# rouge1 average 0.40075719882093785
# rouge2 average 0.37896423673815843
# rougel average 0.4006568395481886
# rougew average 0.13340468636483466
# Blue Average 0.05910958640111192
# rouge1 average 0.40126137578046717
# rouge2 average 0.3794746601310109
# rougel average 0.40116140399525746
# rougew average 0.1335067739422649
# Blue Average 0.05931191603979101
# rouge1 average 0.40189573673416606
# rouge2 average 0.38011174660048536
# rougel average 0.40179614945582254
# rougew average 0.1336464846958219
# Blue Average 0.059624978498275756
# rouge1 average 0.40249636309869835
# rouge2 average 0.3806897607948415
# rougel average 0.4023971573808082
# rougew average 0.1337717830419264
# Blue Average 0.059882679544044956
# rouge1 average 0.40320457333593795
# rouge2 average 0.3813846728990055
# rougel average 0.40310574626582607
# rougew average 0.13392421182731784
# Blue Average 0.060252822791830044
# rouge1 average 0.40390739794399705
# rouge2 average 0.3820743005004762
# rougel average 0.40380894664221256
# rougew average 0.13407548145844775
# Blue Average 0.060620151262065436
# rouge1 average 0.40463832778358355
# rouge2 average 0.38278590841293714
# rougel average 0.4045402494033967
# rougew average 0.1342297158775932
# Blue Average 0.06101932590623183
# rouge1 average 0.40534205590463973
# rouge2 average 0.3834769061016632
# rougel average 0.405244347631548
# rougew average 0.13438516872067077
# Blue Average 0.06138720985204561
# rouge1 average 0.40594801653886387
# rouge2 average 0.3840684076822231
# rougel average 0.405850675590107
# rougew average 0.13451135679342263
# Blue Average 0.06166273502264445
# rouge1 average 0.40661865745357906
# rouge2 average 0.3847226694030813
# rougel average 0.406521681077664
# rougew average 0.13465636568116499
# Blue Average 0.06200084940533712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 15
#      12     thread1 = threading.Thread(target=load_file,
#      13                             args=(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/tech/" + file))
#      14     thread1.start()
# ---> 15     thread1.join()
#      16 if num%4==2:
#      17     thread2 = threading.Thread(target=load_file,
#      18                            args=(os.path.join(root, file), "C:/Users/harsh/Downloads/BBCNews_summary_created/News Articles/tech/" + file))
#
# File ~\anaconda3\Lib\threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\anaconda3\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:
# rouge1 average 0.6071770586929157
# rouge2 average 0.5139022058382423
# rougel average 0.606927920868777
# rougew average 0.21571842510432224
# Blue Average 0.17617119547928864
# rouge1 average 0.6072383553735368
# rouge2 average 0.5139541904719758
# rougel average 0.6069886823463764
# rougew average 0.21572962067213697
# Blue Average 0.17617234785509922
# rouge1 average 0.607336336035336
# rouge2 average 0.514030314426692
# rougel average 0.6070868128719374
# rougew average 0.215752991040317
# Blue Average 0.1761913554526241
# rouge1 average 0.6074923778028094
# rouge2 average 0.5141703830757913
# rougel average 0.6072430043233721
# rougew average 0.21579345603842845
# Blue Average 0.17633696906759122
# rouge1 average 0.607655378434766
# rouge2 average 0.514298779102834
# rougel average 0.6074061544598128
# rougew average 0.21583706855913706
# Blue Average 0.17644865698008308
# rouge1 average 0.6078263518363838
# rouge2 average 0.5144315180465436
# rougel average 0.60757727718676
# rougew average 0.21588735571458442
# Blue Average 0.17656040529065062
# rouge1 average 0.6080095895033714
# rouge2 average 0.5145891173636549
# rougel average 0.6077606640002444
# ...
# rougel average 0.6051473207235546
# rougew average 0.21024090418748922
# Blue Average 0.1809471364695
# rouge1 average 0.605302057712349
# rouge2 average 0.519763510536577
# rougel average 0.6051270846369198
# rougew average 0.21023429855705836
# Blue Average 0.18093258844140003
# rouge1 average 0.6052817945740444
# rouge2 average 0.5197584345182561
# rougel average 0.6051068566903037
# rougew average 0.2102276955837596
# Blue Average 0.18091804626528243
# rouge1 average 0.6052857175230071
# rouge2 average 0.5197777414512065
# rougel average 0.605110814816802
# rougew average 0.21022953490288523
# Blue Average 0.18093270366972738
# rouge1 average 0.6052896388945879
# rouge2 average 0.5197970406210154
# rougel average 0.6051147713517735
# rougew average 0.21023137348243742
# Blue Average 0.18094735518056382
# rouge1 average 0.6053154992594589
# rouge2 average 0.5198264595479547
# rougel average 0.6051406668658995
# rougew average 0.21023937628669967
# Blue Average 0.18097981765827822
# rouge1 average 0.6053413492302927
# rouge2 average 0.5198558666505664
# rougel average 0.6051665519718605
# rougew average 0.21024737587440068
# Blue Average 0.18101226708837298
# rouge1 average 0.6053860827374347
# rouge2 average 0.5199157161746109
# rougel average 0.6052113206000108
# rougew average 0.21026438968800765
# Blue Average 0.1810877641613038
# rouge1 average 0.6054453322252341
# rouge2 average 0.5199767072745687
# rougel average 0.6052706051947081
# rougew average 0.21028310651123813
# Blue Average 0.18117341244306037
# rouge1 average 0.6053237324396898
# rouge2 average 0.5198722733104645
# rougel average 0.6051490405019596
# rougew average 0.21024087250711856
# Blue Average 0.18113702493302963
# rouge1 average 0.6052596100282378
# rouge2 average 0.5198230578329502
# rougel average 0.60508495316921
# rougew average 0.2102186256381785
# Blue Average 0.18110079169973012
# rouge1 average 0.6051771278175752
# rouge2 average 0.5197573929175029
# rougel average 0.6050025060231646
# rougew average 0.21019385484522285
# Blue Average 0.18106449249243356
# rouge1 average 0.6051420648199286
# rouge2 average 0.5197374667397199
# rougel average 0.604967478076059
# rougew average 0.21018119838066293
# Blue Average 0.18103485640326156
# rouge1 average 0.6051002330218263
# rouge2 average 0.5197125513694395
# rougel average 0.6049256813144295
# rougew average 0.21016564967095913
# Blue Average 0.18100467552549465
# rouge1 average 0.6050584180101598
# rouge2 average 0.5196876459973013
# rougel average 0.6048839013251761
# rougew average 0.21015010720070548
# Blue Average 0.18097450675883436
# rouge1 average 0.6050544518249301
# rouge2 average 0.5196987214515497
# rougel average 0.6048799701483085
# rougew average 0.21015035623284795
# Blue Average 0.1809664072432827
# rouge1 average 0.6050504872306292
# rouge2 average 0.519709792463177
# rougel average 0.604876040548327
# rougew average 0.21015060516509784
# Blue Average 0.18095831097663415
# rouge1 average 0.6050715715709565
# rouge2 average 0.519736412000566
# rougel average 0.6048971598689395
# rougew average 0.2101562369041369
# Blue Average 0.18096717812991442
# rouge1 average 0.605092647457258
# rouge2 average 0.5197630208645239
# rougel average 0.6049182707215005
# rougew average 0.21016186638506087
# Blue Average 0.1809760417278004
# rouge1 average 0.6051137148946174
# rouge2 average 0.5197896190614688
# rougel average 0.604939373111102
# rougew average 0.2101674936092276
# Blue Average 0.1809849017724301
# rouge1 average 0.6051428212864078
# rouge2 average 0.5198218050550982
# rougel average 0.6049685144411256
# rougew average 0.2101755432974027
# Blue Average 0.18099958684690104
# rouge1 average 0.6051719160146473
# rouge2 average 0.5198539781511147
# rougel average 0.6049976440935977
# rougew average 0.2101835897598963
# Blue Average 0.18101426603674986
# rouge1 average 0.6052187576251415
# rouge2 average 0.5198937144460071
# rougel average 0.6050445206143326
# rougew average 0.210197236582298
# Blue Average 0.18103895388546615
# rouge1 average 0.6052655804727235
# rouge2 average 0.519933434824098
# rougel average 0.6050913783581715
# rougew average 0.21021087793831783
# Blue Average 0.18106363184519836
# rouge1 average 0.6053123845686645
# rouge2 average 0.5199731392949491
# rougel average 0.6051382173363942
# rougew average 0.21022451383123952
# Blue Average 0.18108829992188702
# rouge1 average 0.6053697218367624
# rouge2 average 0.5200177052839574
# rougel average 0.6051955894728067
# rougew average 0.2102442361743151
# Blue Average 0.18112001000040412
# rouge1 average 0.6054265774175052
# rouge2 average 0.5200602348689025
# rougel average 0.6052524799079058
# rougew average 0.21026502682072012
# Blue Average 0.1811480031192495
# rouge1 average 0.6053054194072155
# rouge2 average 0.5199561603772337
# rougel average 0.6051313567380223
# rougew average 0.2102229485684046
# Blue Average 0.1811117517678148
# rouge1 average 0.6052403221961773
# rouge2 average 0.51990524612459
# rougel average 0.6050662943534485
# rougew average 0.21020286104843158
# Blue Average 0.18107568582365785
# rouge1 average 0.6051752510292323
# rouge2 average 0.5198543522417212
# rougel average 0.6050012579990345
# rougew average 0.21018278156507392
# Blue Average 0.18103963430876444
# rouge1 average 0.6051443632043945
# rouge2 average 0.5198257502702512
# rougel average 0.6049704049728027
# rougew average 0.21017469451034324
# Blue Average 0.18100745259817544
# rouge1 average 0.6051134877322161
# rouge2 average 0.5197971597372822
# rougel average 0.6049395642853138
# rougew average 0.21016661068978762
# Blue Average 0.1809752837576967
# rouge1 average 0.6050826246052885
# rouge2 average 0.5197685806359538
# rougel average 0.6049087359291673
# rougew average 0.21015853010146734
# Blue Average 0.18094312777960916
# rouge1 average 0.6050880048522193
# rouge2 average 0.5197760452867275
# rougel average 0.6049141509329792
# rougew average 0.21016235760257979
# Blue Average 0.18093880863639478
# rouge1 average 0.6050933829487716
# rouge2 average 0.5197835069540278
# rougel average 0.6049195637725209
# rougew average 0.2101661835739156
# Blue Average 0.18093449121945668
# rouge1 average 0.6051178281990246
# rouge2 average 0.5198085094067545
# rougel average 0.60494404375188
# rougew average 0.21017716357112023
# Blue Average 0.18095029579834757
# rouge1 average 0.6051422636828971
# rouge2 average 0.519833501870487
# rougel average 0.6049685139509838
# rougew average 0.21018813918159007
# Blue Average 0.18096609406298403
# rouge1 average 0.605166689406241
# rouge2 average 0.5198584843512103
# rougel average 0.604992974375692
# rougew average 0.2101991104079535
# Blue Average 0.18098188601714926
# rouge1 average 0.6052107294283514
# rouge2 average 0.519890732244152
# rougel average 0.6050367112164233
# rougew average 0.2102158684326295
# Blue Average 0.18101085224327865
# rouge1 average 0.6052547518661049
# rouge2 average 0.5199229672611134
# rougel average 0.6050804305938523
# rougew average 0.21023261976613972
# Blue Average 0.18103980690373578
# rouge1 average 0.6053022650170549
# rouge2 average 0.5199561331643336
# rougel average 0.6051279785394674
# rougew average 0.21025107039908655
# Blue Average 0.18107542278858701
# rouge1 average 0.6051814703124018
# rouge2 average 0.5198523702161867
# rougel average 0.6050072186155921
# rougew average 0.21020911249240143
# Blue Average 0.18103928720231907
# rouge1 average 0.6051571367142767
# rouge2 average 0.5198400118937
# rougel average 0.6049829197843659
# rougew average 0.2102027552702309
# Blue Average 0.1810118237372075
# rouge1 average 0.6051328128243497
# rouge2 average 0.5198276585017229
# rougel average 0.604958630647467
# rougew average 0.21019640058435488
# Blue Average 0.18098437122899405
# rouge1 average 0.6051602490786595
# rouge2 average 0.5198680707501759
# rougel average 0.6049861016409425
# rougew average 0.21020963149303973
# Blue Average 0.18100357372650527
# rouge1 average 0.6051692759082403
# rouge2 average 0.5198738499134785
# rougel average 0.6049951631958349
# rougew average 0.2102143478806182
# Blue Average 0.18099534260612707
# rouge1 average 0.605178299138607
# rouge2 average 0.5198796267724896
# rougel average 0.6050042211376673
# rougew average 0.21021906238765936
# Blue Average 0.18098711476769475
# rouge1 average 0.6052271339811186
# rouge2 average 0.5199225135790014
# rougel average 0.6050530906778072
# rougew average 0.21023942933807427
# Blue Average 0.18102593536066525
# rouge1 average 0.6052759493597631
# rouge2 average 0.5199653832923262
# rougel average 0.6051019407402507
# rougew average 0.2102597881709322
# Blue Average 0.18106474048109966
# rouge1 average 0.6053339839831499
# rouge2 average 0.5200221555291056
# rougel average 0.6051600100336155
# rougew average 0.21028717733033225
# Blue Average 0.1811332240747304
# rouge1 average 0.6053919954851728
# rouge2 average 0.5200789051474638
# rougel average 0.6052180561918036
# rougew average 0.2103145555777166
# Blue Average 0.1812016803840609
# rouge1 average 0.6054501437627806
# rouge2 average 0.520123588229832
# rougel average 0.6052762391117723
# rougew average 0.21034362765159223
# Blue Average 0.1812555211448734
# rouge1 average 0.6055000949458899
# rouge2 average 0.5201725313163761
# rougel average 0.605326224923446
# rougew average 0.21037059582597975
# Blue Average 0.1813347992202536
# rouge1 average 0.6055500262400152
# rouge2 average 0.5202214549153285
# rougel average 0.6053761908323478
# rougew average 0.21039755326249174
# Blue Average 0.1814140457296074
# rouge1 average 0.6054294947857477
# rouge2 average 0.5201179076512131
# rougel average 0.6052556939790771
# rougew average 0.21035567476860986
# Blue Average 0.18137793624598286
# rouge1 average 0.6053780947782056
# rouge2 average 0.5200814066420686
# rougel average 0.6052043285587602
# rougew average 0.2103416444000842
# Blue Average 0.18134267119226308
# rouge1 average 0.6052881019275939
# rouge2 average 0.52000145391367
# rougel average 0.6051143702816103
# rougew average 0.21031210620003446
# Blue Average 0.18130659027877477
# rouge1 average 0.6052576797909348
# rouge2 average 0.5199794194087939
# rougel average 0.605083982704658
# rougew average 0.21030368164218885
# Blue Average 0.18127543074608482
# rouge1 average 0.6052272697553642
# rouge2 average 0.5199573936686372
# rougel average 0.6050536072150474
# rougew average 0.21029526043540048
# Blue Average 0.1812442836077993
# rouge1 average 0.6051968718136636
# rouge2 average 0.5199353766879717
# rougel average 0.6050232438055678
# rougew average 0.21028684257767027
# Blue Average 0.18121314885652443
# rouge1 average 0.6051982958054624
# rouge2 average 0.5199461467558292
# rougel average 0.6050247023158574
# rougew average 0.2102911522484526
# Blue Average 0.18120502775235767
# rouge1 average 0.6051997192311742
# rouge2 average 0.5199569125422048
# rougel average 0.6050261602463376
# rougew average 0.21029546020598877
# Blue Average 0.18119690987661632
# rouge1 average 0.6052358358957766
# rouge2 average 0.5199998255840942
# rougel average 0.6050623114019942
# rougew average 0.21031010907278005
# Blue Average 0.18123029162813462
# rouge1 average 0.605271938208436
# rouge2 average 0.5200427215733143
# rougel average 0.6050984481920018
# rougew average 0.2103247521184441
# Blue Average 0.1812636601145023
# rouge1 average 0.6053080261777052
# rouge2 average 0.520085600520028
# rougel average 0.6051345706249215
# rougew average 0.2103393893464499
# Blue Average 0.18129701534362466
# rouge1 average 0.6053580430259604
# rouge2 average 0.5201316416296603
# rougel average 0.6051846219231376
# rougew average 0.2103569886404114
# Blue Average 0.1813408575932459
# rouge1 average 0.6054080400104952
# rouge2 average 0.5201776644544994
# rougel average 0.6052346533439517
# rougew average 0.21037458094497893
# Blue Average 0.18138468243133032
# rouge1 average 0.6054694242691717
# rouge2 average 0.5202258242631623
# rougel average 0.6052960720252343
# rougew average 0.21039666002404753
# Blue Average 0.18143804493581045
# rouge1 average 0.6053492437562163
# rouge2 average 0.5201225638772426
# rougel average 0.6051759259212197
# rougew average 0.21035489808279623
# Blue Average 0.18140203103248853
# rouge1 average 0.6052506286645688
# rouge2 average 0.5200377504895523
# rougel average 0.6050773452248559
# rougew average 0.21032082056163467
# Blue Average 0.1813660314232342
# rouge1 average 0.6051520527058941
# rouge2 average 0.5199529707579681
# rougel average 0.6049788036478162
# rougew average 0.210286756563299
# Blue Average 0.18133004609953912
# rouge1 average 0.6050711041867715
# rouge2 average 0.5198850467694561
# rougel average 0.6048978894966875
# rougew average 0.21025882378696314
# Blue Average 0.18129409544131833
# rouge1 average 0.6049901877773352
# rouge2 average 0.519817149724216
# rougel average 0.6048170074416126
# rougew average 0.2102309020906655
# Blue Average 0.18125815904357284
# rouge1 average 0.6049093034584835
# rouge2 average 0.5197492796062196
# rougel average 0.6047361574634977
# rougew average 0.21020299146781474
# Blue Average 0.18122223689781933
# rouge1 average 0.6048522574168507
# rouge2 average 0.5197015434446115
# rougel average 0.6046791457489853
# rougew average 0.2101818967865956
# Blue Average 0.181187218823067
# rouge1 average 0.6047952339901006
# rouge2 average 0.5196538262071507
# rougel average 0.6046221566357471
# rougew average 0.21016081046798546
# Blue Average 0.18115221463060396
# rouge1 average 0.6047447437326612
# rouge2 average 0.5196114416963253
# rougel average 0.6045717006782194
# rougew average 0.210140724754459
# Blue Average 0.18111766664072074
# rouge1 average 0.6046942734832492
# rouge2 average 0.5195690739814227
# rougel average 0.604521264715127
# rougew average 0.21012064700039892
# Blue Average 0.1810831323413427
# rouge1 average 0.6046438232299742
# rouge2 average 0.519526723052461
# rougel average 0.6044708487345873
# rougew average 0.21010057720107503
# Blue Average 0.18104861172433367
# rouge1 average 0.6046105784489473
# rouge2 average 0.519500929366749
# rougel average 0.6044376382127197
# rougew average 0.210085306047984
# Blue Average 0.18101956633407498
# rouge1 average 0.6045773468341703
# rouge2 average 0.5194751458963581
# rougel average 0.604404440843534
# rougew average 0.2100700409428744
# Blue Average 0.18099053244694116
# rouge1 average 0.6045608476473244
# rouge2 average 0.5194666269219587
# rougel average 0.6043879758887195
# rougew average 0.21006083768353004
# Blue Average 0.18096926012719503
# rouge1 average 0.6045443549922231
# rouge2 average 0.5194581113200747
# rougel average 0.6043715174520978
# rougew average 0.21005163806759794
# Blue Average 0.1809479962287948
# rouge1 average 0.6045278688649885
# rouge2 average 0.5194495990887041
# rougel average 0.6043550655297989
# rougew average 0.21004244209291498
# Blue Average 0.18092674074674064
# rouge1 average 0.6044999052977418
# rouge2 average 0.5194291961340869
# rougel average 0.6043271361539521
# rougew average 0.21003115043090295
# Blue Average 0.18089639658580164
# rouge1 average 0.6044718311392286
# rouge2 average 0.5194093095835599
# rougel average 0.6042990961733111
# rougew average 0.21001922578712096
# Blue Average 0.1808669540023573
# rouge1 average 0.6044600085796079
# rouge2 average 0.5194062954451187
# rougel average 0.6042873077780428
# rougew average 0.2100121280664334
# Blue Average 0.18084948476583612
# rouge1 average 0.6044511041031716
# rouge2 average 0.5194042016574605
# rougel average 0.6042784374524472
# rougew average 0.21000565466847682
# Blue Average 0.18083302725020958
# rouge1 average 0.6044570434949872
# rouge2 average 0.5194142665642106
# rougel average 0.6042844109815998
# rougew average 0.2100026408367018
# Blue Average 0.18082271938942251
# rouge1 average 0.6044574386816994
# rouge2 average 0.5194199356899868
# rougel average 0.6042848402921535
# rougew average 0.20999763896722212
# Blue Average 0.18081185229352115
# rouge1 average 0.6044521432831247
# rouge2 average 0.5194224610725731
# rougel average 0.6042795790039324
# rougew average 0.20999222812178
# Blue Average 0.18080120966822116
# rouge1 average 0.6044628751498143
# rouge2 average 0.5194371280237426
# rougel average 0.604290344967496
# rougew average 0.209990771222154
# Blue Average 0.18079703008462752
# rouge1 average 0.6044810811447712
# rouge2 average 0.5194598019031555
# rougel average 0.6043085850458552
# rougew average 0.20999151247484196
# Blue Average 0.18080598251033458
# rouge1 average 0.6044978346157921
# rouge2 average 0.5194800181135293
# rougel average 0.6043253725868146
# rougew average 0.20999206788266733
# Blue Average 0.18080624393696096
# rouge1 average 0.604513738284629
# rouge2 average 0.5194982844881938
# rougel average 0.6043413103121342
# rougew average 0.20999243179067145
# Blue Average 0.18079762197195332

# %%
nltk.pos_tag(nltk.word_tokenize("hello how are you"))
